# %%
import pandas as pd

# %%
import sqlite3

# %%
  conn = sqlite3.connect('db.sqlite3')

# %%
conn

# %%
sql = SELECT 'nombre' 
      FROM db.sqlite3
# Out:
#   Cell In[23], line 1
#     sql = SELECT :'nombre'
#                  ^
# SyntaxError: invalid syntax

# %%
df = pd.read_sql(sql, con=conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd.read_sql(sql, con=conn)
#
# NameError: name 'sql' is not defined
